# %%
a=[10,34,20]
a.sort()
print(a)
# Out:
# [10, 20, 34]

# %%
a=10
b=10.5
c=5+10j
d="aishita"
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'str'>

# %%
x=5
y="aishita"
print(x)
print(y)
# Out:
# 5
# aishita

# %%
a=10
b=20
c=5
print(a/b)
print(a%b)
print(c%b)
print(c/a)
# Out:
# 0.5
# 10
# 5
# 0.5

# %%
a = 33
b = 200
if b > a:
  print("b is greater than a")
# Out:
# b is greater than a

# %%
age=20
if age >=18:
   print("eligible to vote")
   print("you are an adult and can access your legal rights")
# Out:
# eligible to vote
# you are an adult and can access your legal rights

# %%
login_complete= True
if login_complete:
  print("welcome back user!")
# Out:
# welcome back user!

# %%
hrs_std = 4
attendance = 60
if hrs_std >= 4:
  if attendance == 60:
    print("is eligible to sit for exams")
  else:
    print("not eligible")
# Out:
# is eligible to sit for exams

# %%
students=10
marks=int(input("marks"))
pass_criteria=40
if marks >=pass_criteria:
  print("pass")
else:
  print("fail")
# Out:
# marks45
# pass
